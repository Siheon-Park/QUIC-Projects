# %%
import sys
sys.path
# Out:
# ['/home/quic/QUIC-Projects',
#  '/home/quic/QUIC-Projects/custom_qiskit',
#  '/home/quic/QUIC-Projects',
#  '/home/quic/.vscode-server/extensions/ms-python.python-2020.9.114305/pythonFiles',
#  '/home/quic/.vscode-server/extensions/ms-python.python-2020.9.114305/pythonFiles/lib/python',
#  '/home/quic/anaconda3/lib/python38.zip',
#  '/home/quic/anaconda3/lib/python3.8',
#  '/home/quic/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/home/quic/.local/lib/python3.8/site-packages',
#  '/home/quic/anaconda3/lib/python3.8/site-packages',
#  '/home/quic/.local/lib/python3.8/site-packages/IPython/extensions',
#  '/home/quic/.ipython']

# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit(2)
qc.initialize([0,1,0,0], [0,1])

# %%
import numpy as np
a = [[2, 3], [3, 4], [5,6]]
np.size(a, 0)
# Out:
# 3

# %%
from quantumdatabase.QDB import *
from qiskit import QuantumCircuit
qc = QuantumCircuit(1)
qc.qdb([1, 1], [0])
qc.draw()
# Out:
#      ┌──────────────────────┐
# q_0: ┤ QDB(0.70711,0.70711) ├
#      └──────────────────────┘

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

state = Statevector.from_instruction(qc)
plot_state_qsphere(state, show_state_phases=True)

# %%
from swap_classifier import SWAP_classifier, Classical_SWAP_classifer, SPSA
from datageneration import DataGeneration
import numpy as np

X, y = DataGeneration(2, 2**3, 1, 0.1, True)
classical = Classical_SWAP_classifer(X, y)
classical.weight_qc.draw('mpl')
