# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import Aer, IBMQ, execute
from qiskit.circuit import Parameter
import math
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
N=100
n = math.ceil(math.log(N, 2))
random_state = np.random.random(2**n)
qc = QuantumCircuit(n)
#qc.initialize(random_state/np.linalg.norm(random_state), range(n))
qc.draw('mpl')

# %%
import quantumdatabase.QDB
qc = QuantumCircuit(n)
qc.qdb(random_state, list(range(n)))
qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

state = Statevector.from_instruction(qc)
plot_state_qsphere(state, show_state_phases=True)

# %%
random_state
# Out:
# array([0.21184284, 0.57622554, 0.59716431, 0.8914877 , 0.92383441,
#        0.22759454, 0.52788206, 0.90956694, 0.18068504, 0.73074124,
#        0.2597827 , 0.58507141, 0.65138061, 0.26204726, 0.7620392 ,
#        0.98138634, 0.98153473, 0.5703615 , 0.80080635, 0.14214919,
#        0.31628713, 0.88894684, 0.90272044, 0.85732933, 0.36430546,
#        0.1388402 , 0.30962389, 0.19220843, 0.70618945, 0.99733973,
#        0.66417344, 0.35415435, 0.97160467, 0.82351795, 0.81772448,
#        0.55440989, 0.13882946, 0.64924386, 0.97256295, 0.337661  ,
#        0.99467417, 0.83351551, 0.71040432, 0.68507227, 0.91756732,
#        0.46558481, 0.40847443, 0.8065761 , 0.77066677, 0.46250358,
#        0.07834781, 0.10680798, 0.18153427, 0.20189369, 0.22620284,
#        0.36868939, 0.26915659, 0.91852231, 0.77737575, 0.78522461,
#        0.14347376, 0.94335809, 0.44154452, 0.34022291, 0.06623897,
#        0.39837056, 0.12572169, 0.24027476, 0.59768165, 0.74268932,
#        0.51283469, 0.79564941, 0.99505207, 0.65069042, 0.31343361,
#        0.38756054, 0.56227717, 0.98757163, 0.27592301, 0.8516389 ,
#        0.8347315 , 0.21761869, 0.84727394, 0.03513308, 0.44638883,
#        0.80663631, 0.20789434, 0.30422893, 0.48175175, 0.73988471,
#        0.63535211, 0.49296316, 0.74465411, 0.33860479, 0.71930705,
#        0.5423167 , 0.60376863, 0.56744317, 0.72363928, 0.79330381,
#        0.69195097, 0.59391955, 0.07667613, 0.35707477, 0.81950347,
#        0.09548114, 0.29747708, 0.52258157, 0.9376423 , 0.34517885,
#        0.11662294, 0.39326777, 0.85923526, 0.20025771, 0.29614282,
#        0.29092235, 0.40829156, 0.13847224, 0.04191838, 0.59203619,
#        0.45037083, 0.42501837, 0.33336919, 0.69548057, 0.81469603,
#        0.24705268, 0.38793326, 0.06119421])

# %%
qc.decompose().draw('mpl')

# %%
from qiskit import transpile
qc = transpile(qc, basis_gates=['cx', 'u3'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7ccea725e136> in <module>
#       1 from qiskit import transpile
# ----> 2 qc = transpile(qc, basis_gates=['cx', 'u3'])
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     205
#     206     # Get transpile_args to configure the circuit transpilation job(s)
# --> 207     transpile_args = _parse_transpile_args(circuits, backend, basis_gates, coupling_map,
#     208                                            backend_properties, initial_layout,
#     209                                            layout_method, routing_method, translation_method,
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpile.py in _parse_transpile_args(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, seed_transpiler, optimization_level, callback, output_name)
#     412     seed_transpiler = _parse_seed_transpiler(seed_transpiler, num_circuits)
#     413     optimization_level = _parse_optimization_level(optimization_level, num_circuits)
# --> 414     output_name = _parse_output_name(output_name, circuits)
#     415     callback = _parse_callback(callback, num_circuits)
#     416
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpile.py in _parse_output_name(output_name, circuits)
#     665                                   "list of strings: %s was used." % type(output_name))
#     666     else:
# --> 667         return [circuit.name for circuit in circuits]
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpile.py in <listcomp>(.0)
#     665                                   "list of strings: %s was used." % type(output_name))
#     666     else:
# --> 667         return [circuit.name for circuit in circuits]
#
# AttributeError: 'Figure' object has no attribute 'name'

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(3)
qc.cswap(ctl=0, tgt1=1, tgt2=2)
qc.draw()
# Out:
#
# q_0: ─■─
#       │
# q_1: ─X─
#       │
# q_2: ─X─
