# %%
import numpy as np 
import matplotlib.pyplot as plt
import dill
from datageneration import iris_data

# %%
X, y = iris_data()
for i in range(1, 2):
    with open(f'./multiprocess/iris_Duel_swp_id{i}_lr5_iter1000.dill', 'rb') as f:
        swp = dill.load(f)
        '''
    print(f'{i}: {swp.check_performance(X, y)}')
    print(f'{i} random: {swp.check_performance_if(X, y, np.random.rand(len(swp.theta)))}')
    '''
    print(np.sum(swp.alpha))
# Out:
# 0.9988331413720379

# %%
from sklearn import svm
from datageneration import DataGeneration
from swap_classifier import Classical_SWAP_classifier
C=100
X, y = iris_data()
Xt, yt = iris_data()
clf = svm.SVC(kernel='poly', degree=2, gamma=1, coef0=0, C=C)
clf.fit(X, y)
print(np.sum(clf.predict(Xt)==yt)/len(yt))
alpha = np.zeros(len(y))
alpha[clf.support_]=np.abs(clf.dual_coef_)
plt.plot(alpha)
clf.score(X, y)
np.sum(alpha*y)
plt.figure()
swp = Classical_SWAP_classifier(X, y)
swp.alpha = np.abs(alpha)
swp.plot()
# Out:
# 1.0

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from datageneration import iris_data


def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(ax, clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

title = 'power2 kernel svm (iris data)'

# Set-up 2x2 grid for plotting.
fig, ax = plt.subplots(1, 1)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, clf, xx, yy,
                cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_xlabel('Sepal length')
ax.set_ylabel('Sepal width')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
from swap_classifier import Classical_SWAP_Duel_Classifier, SPSA
from datageneration import DataGeneration
import numpy as np

X, y = DataGeneration(2, 2**10, 1, 0.1, True)
dswap = Classical_SWAP_Duel_Classifier(X, y, 9, 4)
dswap.optimize(SPSA(maxiter=1000, save_steps=100), initial_point=np.random.rand(len(dswap.theta)))

# %%
import matplotlib.pyplot as plt
dswap.plot(sv = False)

# %%
plt.plot(swp.alpha)
