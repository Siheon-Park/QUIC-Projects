# %%
import sys
sys.path.extend(['/home/quic/QUIC-Projects'])

import numpy as np 
import matplotlib.pyplot as plt

# %%
from pandas import DataFrame, read_csv
import seaborn as sns
data = read_csv('./Exp6(pseudo_iris_hard)/summary.csv')
data_std = read_csv('./pqc_prop_std(trs=64).csv')

expr = data['expr']
num_params = data['num_params']
expr_std = data_std['expr']

plt.errorbar(y=num_params, x=expr, xerr=expr_std, linestyle='none', marker='.')
plt.xscale('log')
