# %%
import sys
quic_path = '/home/quic/QUIC-Projects'
if not quic_path in sys.path:
    sys.path.append(quic_path)

# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
# for SVM
from classifiers.convex.svm import BinarySVM
from classifiers.kernel import Kernel
# for QASVM
from classifiers.quantum import Qasvm_Mapping_4x2
from classifiers.quantum.qasvm import QASVM
from classifiers.optimizer import MySPSA
from qiskit.aqua import QuantumInstance
from qiskit.ignis.mitigation import CompleteMeasFitter
from qiskit.circuit.library import RealAmplitudes, EfficientSU2, NLocal, TwoLocal
from qiskit.providers.aer import QasmSimulator
from qiskit import IBMQ
# for logging & visualization
import logging
from classifiers.callback import SimplePMStorage, SimpleStorage
from torch.utils.tensorboard import SummaryWriter
from classifiers.visualization import Plot_Data, Plot_Log_From_SPSA, Plot_SVM, compare_svm_and_qasvm

writer = SummaryWriter(comment='SPSA')
storage = SimplePMStorage(writer)

if IBMQ.active_account() is None:
    IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-kaist', group='internal', project='default')
backend = provider.get_backend('ibmq_toronto')
backend
# Out:
# /home/quic/anaconda3/envs/quic/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# <IBMQBackend('ibmq_toronto') from IBMQ(hub='ibm-q-kaist', group='internal', project='default')>

# %%
from classifiers.datasets.dataloader import Example_4x2
X, y = Example_4x2(False)()
Plot_Data(X, y).plot()

# %%
var_form = RealAmplitudes(2, reps=5)
#var_form = TwoLocal(2, rotation_blocks='ry', reps=1, skip_final_rotation_layer=True)
quantum_instance = QuantumInstance(backend=QasmSimulator(), seed_transpiler=0, basis_gates=backend.configuration().basis_gates, optimization_level=2, shots=2**13, initial_layout=Qasvm_Mapping_4x2(backend).layout)
optimizer = MySPSA(maxiter=2**13, save_steps=2**10, callback=storage)
qasvm = QASVM(X, y, var_form=var_form, quantum_instance=quantum_instance, optimizer=optimizer, C=None, k=0.1).dual
print(qasvm.second_order_circuit.depth())
qasvm.second_order_circuit.draw(fold=-1, idle_wires=False)
# Out:
# 16
#           ┌───┐                                                                                                                                                                                                     ┌───┐┌─┐
#  a_0: ────┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■─┤ H ├┤M├
#       ┌───┴───┴────┐     ┌────────────┐     ┌────────────┐     ┌────────────┐     ┌────────────┐     ┌─────────────┐┌──────────────────────────────────┐┌─────────────────────────────────────┐┌────────────────┐ │ └───┘└╥┘
#  i_0: ┤ RY(θ_i[0]) ├──■──┤ RY(θ_i[2]) ├──■──┤ RY(θ_i[4]) ├──■──┤ RY(θ_i[6]) ├──■──┤ RY(θ_i[8]) ├──■──┤ RY(θ_i[10]) ├┤1                                 ├┤1                                    ├┤1               ├─┼───────╫─
#       ├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├─────────────┤│                                  ││                                     ││                │ │       ║
#  i_1: ┤ RY(θ_i[1]) ├┤ X ├┤ RY(θ_i[3]) ├┤ X ├┤ RY(θ_i[5]) ├┤ X ├┤ RY(θ_i[7]) ├┤ X ├┤ RY(θ_i[9]) ├┤ X ├┤ RY(θ_i[11]) ├┤2 UCRY(1.5212,1.7253,1.6123,1.81) ├┤2 UCRZ(-2.0053,1.3094,1.1238,1.2136) ├┤2               ├─┼───────╫─
#       └────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└─────────────┘│                                  ││                                     ││  UCRX(π,0,0,0) │ │       ║
# xi_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                                 ├┤0                                    ├┤                ├─X───────╫─
#                                                                                                                     └──────────────────────────────────┘└─────────────────────────────────────┘│                │ │  ┌─┐  ║
# yi_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0               ├─┼──┤M├──╫─
#       ┌────────────┐     ┌────────────┐     ┌────────────┐     ┌────────────┐     ┌────────────┐     ┌─────────────┐┌──────────────────────────────────┐┌─────────────────────────────────────┐├────────────────┤ │  └╥┘  ║
#  j_0: ┤ RY(θ_j[0]) ├──■──┤ RY(θ_j[2]) ├──■──┤ RY(θ_j[4]) ├──■──┤ RY(θ_j[6]) ├──■──┤ RY(θ_j[8]) ├──■──┤ RY(θ_j[10]) ├┤1                                 ├┤1                                    ├┤1               ├─┼───╫───╫─
#       ├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├────────────┤┌─┴─┐├─────────────┤│                                  ││                                     ││                │ │   ║   ║
#  j_1: ┤ RY(θ_j[1]) ├┤ X ├┤ RY(θ_j[3]) ├┤ X ├┤ RY(θ_j[5]) ├┤ X ├┤ RY(θ_j[7]) ├┤ X ├┤ RY(θ_j[9]) ├┤ X ├┤ RY(θ_j[11]) ├┤2 UCRY(1.5212,1.7253,1.6123,1.81) ├┤2 UCRZ(-2.0053,1.3094,1.1238,1.2136) ├┤2               ├─┼───╫───╫─
#       └────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└────────────┘└───┘└─────────────┘│                                  ││                                     ││  UCRX(π,0,0,0) │ │   ║   ║
# xj_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                                 ├┤0                                    ├┤                ├─X───╫───╫─
#                                                                                                                     └──────────────────────────────────┘└─────────────────────────────────────┘│                │┌─┐  ║   ║
# yj_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0               ├┤M├──╫───╫─
#                                                                                                                                                                                                └────────────────┘└╥┘  ║   ║
#  c: 3/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═══╩═══╩═
#                                                                                                                                                                                                                   2   1   0

# %%
qasvm.run()
# Out:
#   0%|          | 0/8192 [00:00<?, ?it/s]
# {'optimizer_evals': None,
#  'optimizer_time': 9550.78908109665,
#  'optimal_value': 0.517822265625,
#  'optimal_point': array([ 1.26110931,  1.82102388,  0.52861001, -2.4228356 , -3.1848448 ,
#          0.19963164,  3.39220083, -2.51714619, -5.77275816,  0.70549424,
#         -1.55019464,  0.21941487]),
#  'optimal_parameters': {Parameter(θ[0]): 1.2611093119995713,
#   Parameter(θ[1]): 1.8210238810814028,
#   Parameter(θ[2]): 0.5286100146009323,
#   Parameter(θ[3]): -2.42283560264832,
#   Parameter(θ[4]): -3.184844800987882,
#   Parameter(θ[5]): 0.1996316406860613,
#   Parameter(θ[6]): 3.39220083105698,
#   Parameter(θ[7]): -2.517146194692707,
#   Parameter(θ[8]): -5.772758156277164,
#   Parameter(θ[9]): 0.7054942414352835,
#   Parameter(θ[10]): -1.5501946362936088,
#   Parameter(θ[11]): 0.21941486723837447}}

# %%
storage.plot()

# %%
storage.plot_params()

# %%
svm = BinarySVM(kernel=Kernel('SingleQubit'), mutation='REDUCED_QASVM', C=None, k=0.1)
svm.fit(X, y)
compare_svm_and_qasvm(svm=svm, qasvm=qasvm, repeat_for_qasvm=100)

# %%
plt.plot(qasvm.alpha)
plt.plot(svm.alpha)
