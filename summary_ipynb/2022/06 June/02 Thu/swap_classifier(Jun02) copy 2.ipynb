# %%
import sys
quic_path = '/home/quic/QUIC-Projects'
if not quic_path in sys.path:
    sys.path.append(quic_path)

# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
# for SVM
from classifiers.convex.svm import BinarySVM
from classifiers.kernel import Kernel
from classifiers.datasets import IrisDataset
# for QASVM
from classifiers.quantum.qasvm import SoftQASVM, PseudoSoftQASVM
from classifiers.convex.svm import CvxSoftQASVM
from classifiers.quantum.ansatz import Circuit9, sample_circuit
from classifiers.callback import CostParamStorage
from qiskit.utils import QuantumInstance
from qiskit.providers.aer import AerSimulator, StatevectorSimulator, Aer, QasmSimulator
# for optimization
from qiskit.algorithms.optimizers import SPSA, ADAM
from tqdm.notebook import tqdm

# %%
iris_dataset = IrisDataset(feature_range=(-np.pi, np.pi))
iris_data, iris_label, iris_names, iris_features = iris_dataset.data, iris_dataset.target, iris_dataset.target_names, iris_dataset.feature_names

classes = list(iris_names)
ds = {__l:IrisDataset(feature_range=(-np.pi, np.pi), true_hot=__l) for __l in classes}
training_set = IrisDataset(feature_range=(-np.pi, np.pi)).sample(2**7, random_state = 83495)
trainind_data = training_set[training_set.columns[0:-2]].to_numpy()
training_labels = {__l: ds[__l].frame.iloc[training_set.index].target.to_numpy() for __l in classes}

# %%
backend = StatevectorSimulator(device='CPU', shots=2**13)
backend.options
# Out:
# Options(shots=8192, device='CPU', precision='double', executor=None, max_job_size=None, max_shot_size=None, zero_threshold=1e-10, validation_threshold=None, max_parallel_threads=None, max_parallel_experiments=None, max_parallel_shots=None, max_memory_mb=None, seed_simulator=None, fusion_enable=True, fusion_verbose=False, fusion_max_qubit=5, fusion_threshold=14, statevector_parallel_threshold=14)

# %%
_feature_map = Circuit9(4, reps=1)
feature_map = _feature_map.copy()
for _ in range(2 - 1):
    feature_map.compose(_feature_map, inplace=True)

var_form = sample_circuit(15)(num_qubits=7, reps=5)
quantum_instance = QuantumInstance(backend=backend, shots=2**13)

MAXITER = 2**13

# %%
label_index = 1

from tqdm.notebook import tqdm
from itertools import product

from sklearn.svm import SVC
__qasvm = PseudoSoftQASVM(
        trainind_data, training_labels['setosa'], lamda=1, C=10,
        quantum_instance=quantum_instance,
        var_form=None,
        feature_map=feature_map
    )
kernel_matrix = __qasvm.kernel_matrix
hyperC = 10**np.linspace(-4, 4, 5)
lamdas = 10**np.linspace(-10, 10, 5)
X, Y = np.meshgrid(hyperC, lamdas)
Z = np.empty_like(X)

# %%
with tqdm(total = len(X.flatten())) as pbar:
    for i, _X in enumerate(X):
        for j, _ in enumerate(_X):
            svm = SVC(C=X[i, j], kernel='precomputed')
            svm.fit(kernel_matrix+1/Y[i, j], np.where(training_set['target'].to_numpy()==label_index, 1, 0))
            accuracy = svm.score(__qasvm._qk.evaluate(iris_data, trainind_data)+1/Y[i, j], np.where(iris_label==label_index, 1, 0))
            Z[i, j] = accuracy
            pbar.update()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots()
cs = ax.imshow(Z, interpolation='gaussian')
ax.set_xlabel('C')
ax.set_ylabel(r'$\lambda$')
ax.set_xticks(np.arange(len(hyperC)))
ax.set_xticklabels(list(map(r'$10^{{{:1.0f}}}$'.format, np.log10(hyperC))))
ax.set_yticks(np.arange(len(lamdas)))
ax.set_yticklabels(list(map(r'$10^{{{:1.0f}}}$'.format, np.log10(lamdas))))
ax.set_title('SVM')
fig.colorbar(cs)

# %%
Z_ = np.empty_like(Z)
with tqdm(total = len(X.flatten())) as pbar:
    def callback(*args):
        pass
    for i, _X in enumerate(X):
        for j, _ in enumerate(_X):
            qasvm = CvxSoftQASVM(kernel='precomputed', C=X[i, j], lamda=Y[i, j])
            qasvm.fit(kernel_matrix, np.where(training_set['target'].to_numpy()==label_index, 1, 0))
            accuracy2 = qasvm.score(__qasvm._qk.evaluate(iris_data, trainind_data), np.where(iris_label==label_index, 1, 0))

            Z_[i, j] = accuracy2
            pbar.update()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots()
cs = ax.imshow(Z_, interpolation='gaussian')
ax.set_xlabel('C')
ax.set_ylabel(r'$\lambda$')
ax.set_xticks(np.arange(len(hyperC)))
ax.set_xticklabels(list(map(r'$10^{{{:1.0f}}}$'.format, np.log10(hyperC))))
ax.set_yticks(np.arange(len(lamdas)))
ax.set_yticklabels(list(map(r'$10^{{{:1.0f}}}$'.format, np.log10(lamdas))))
ax.set_title('QASVM')
fig.colorbar(cs)

# %%
layers = np.arange(1, 21, 2)
var_forms = [sample_circuit(15)(num_qubits=7, reps=_r) for _r in layers]
accuracy_list = []
num_params_list = []
last_cost_list = []
qasvm_list = []
result_list = []

for i, layer in enumerate(tqdm(layers)):
    qasvm = PseudoSoftQASVM(
        data=trainind_data, label=np.where(training_set['target'].to_numpy()==label_index, 1, 0),
        quantum_instance=quantum_instance,
        feature_map=feature_map,
        var_form=var_forms[i],
        lamda=10**4, C=10
    )
    with tqdm(total=2**10) as pbar:
        pbar.set_description(f'layer: {layer}')
        def callback(*args):
            pbar.update()
        optimzer = SPSA(maxiter=2**10, blocking=True, callback=callback)
        result = optimzer.minimize(qasvm.cost_fn, qasvm.initial_point)
    qasvm.parameters = result.x
    accuracy = qasvm.accuracy(iris_data, np.where(iris_label==label_index, 1, 0))
    accuracy_list.append(accuracy)
    num_params_list.append(qasvm.num_parameters)
    last_cost_list.append(result.fun)
    qasvm_list.append(qasvm)
    result_list.append(result)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-50f162d1a11f> in <module>
#      20             pbar.update()
#      21         optimzer = SPSA(maxiter=2**10, blocking=True, callback=callback)
# ---> 22         result = optimzer.minimize(qasvm.cost_fn, qasvm.initial_point)
#      23     qasvm.parameters = result.x
#      24     accuracy = qasvm.accuracy(iris_data, np.where(iris_label==label_index, 1, 0))
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in minimize(self, fun, x0, jac, bounds)
#     549             iteration_start = time()
#     550             # compute update
# --> 551             fx_estimate, update = self._compute_update(fun, x, k, next(eps), lse_solver)
#     552
#     553             # trust region
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _compute_update(self, loss, x, k, eps, lse_solver)
#     484
#     485         # accumulate the number of samples
# --> 486         value, gradient, hessian = self._point_estimate(loss, x, eps, num_samples)
#     487
#     488         # precondition gradient with inverse Hessian, if specified
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _point_estimate(self, loss, x, eps, num_samples)
#     461             delta2 = deltas2[i] if self.second_order else None
#     462
# --> 463             value_sample, gradient_sample, hessian_sample = self._point_sample(
#     464                 loss, x, eps, delta1, delta2
#     465             )
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _point_sample(self, loss, x, eps, delta1, delta2)
#     422
#     423         # batch evaluate the points (if possible)
# --> 424         values = _batch_evaluate(loss, points, self._max_evals_grouped)
#     425
#     426         plus = values[0]
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _batch_evaluate(function, points, max_evals_grouped)
#     689     if max_evals_grouped == 1:
#     690         # support functions with multiple arguments where the points are given in a tuple
# --> 691         return [
#     692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in <listcomp>(.0)
#     690         # support functions with multiple arguments where the points are given in a tuple
#     691         return [
# --> 692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#     694
#
# ~/QUIC-Projects/classifiers/quantum/qasvm.py in cost_fn(self, params)
#     753
#     754     def cost_fn(self, params: np.ndarray):
# --> 755         alpha = self.alpha(params)
#     756         if self.C is not None:
#     757             return super().cost_fn(params) + np.sum(alpha ** 2).item()/self.C
#
# ~/QUIC-Projects/classifiers/quantum/qasvm.py in alpha(self, params)
#     713             #     result = self.quantum_instance.execute(var_qc)
#     714             #     return # np.abs(result.get_statevector()) ** 2
# --> 715             return Statevector(var_qc).probabilities()
#     716
#     717     def cost_fn(self, params: np.ndarray):
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in __init__(self, data, dims)
#      87             self._data = np.ravel(data.data)
#      88         elif isinstance(data, (QuantumCircuit, Instruction)):
# ---> 89             self._data = Statevector.from_instruction(data).data
#      90         else:
#      91             raise QiskitError("Invalid input data format for Statevector")
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in from_instruction(cls, instruction)
#     736         init[0] = 1.0
#     737         vec = Statevector(init, dims=instruction.num_qubits * (2,))
# --> 738         return Statevector._evolve_instruction(vec, instruction)
#     739
#     740     def to_dict(self, decimals=None):
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_instruction(statevec, obj, qargs)
#     876             else:
#     877                 new_qargs = [qargs[qubits[tup]] for tup in qregs]
# --> 878             Statevector._evolve_instruction(statevec, instr, qargs=new_qargs)
#     879         return statevec
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_instruction(statevec, obj, qargs)
#     876             else:
#     877                 new_qargs = [qargs[qubits[tup]] for tup in qregs]
# --> 878             Statevector._evolve_instruction(statevec, instr, qargs=new_qargs)
#     879         return statevec
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_instruction(statevec, obj, qargs)
#     842             # Perform the composition and inplace update the current state
#     843             # of the operator
# --> 844             return Statevector._evolve_operator(statevec, Operator(mat), qargs=qargs)
#     845
#     846         # Special instruction types
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_operator(statevec, oper, qargs)
#     821         # Reshape input for contraction
#     822         statevec._data = np.reshape(
# --> 823             np.transpose(np.reshape(statevec.data, statevec._op_shape.tensor_shape), axes),
#     824             contract_shape,
#     825         )
#
# <__array_function__ internals> in transpose(*args, **kwargs)
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/numpy/core/fromnumeric.py in transpose(a, axes)
#     656
#     657     """
# --> 658     return _wrapfunc(a, 'transpose', axes)
#     659
#     660
#
# ~/anaconda3/envs/qiskit/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].plot(num_params_list, accuracy_list, label='accuracy')
axes[1].plot(num_params_list, last_cost_list, label='training cost')
axes[0].legend()
axes[1].legend()

# %%
layers = np.arange(1, 21, 2)
var_forms = [sample_circuit(9)(num_qubits=7, reps=_r) for _r in layers]
_accuracy_list = []
_num_params_list = []
_last_cost_list = []
_qasvm_list = []
_result_list = []

for i, layer in enumerate(tqdm(layers)):
    qasvm = PseudoSoftQASVM(
        data=trainind_data, label=np.where(training_set['target'].to_numpy()==label_index, 1, 0),
        quantum_instance=quantum_instance,
        feature_map=feature_map,
        var_form=var_forms[i],
        lamda=10**4, C=10
    )
    with tqdm(total=2**10) as pbar:
        pbar.set_description(f'layer: {layer}')
        def callback(*args):
            pbar.update()
        optimzer = SPSA(maxiter=2**10, blocking=True, callback=callback)
        result = optimzer.minimize(qasvm.cost_fn, qasvm.initial_point)
    qasvm.parameters = result.x
    accuracy = qasvm.accuracy(iris_data, np.where(iris_label==label_index, 1, 0))
    _accuracy_list.append(accuracy)
    _num_params_list.append(qasvm.num_parameters)
    _last_cost_list.append(result.fun)
    _qasvm_list.append(qasvm)
    _result_list.append(result)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].plot(_num_params_list, _accuracy_list, label='accuracy')
axes[1].plot(_num_params_list, _last_cost_list, label='training cost')
axes[0].legend()
axes[1].legend()

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 15

plt.plot(_num_params_list, _last_cost_list, label='circuit #9', color='#D81B60')
for _x, _y, _a in zip(_num_params_list, _last_cost_list, _accuracy_list):
    plt.scatter([_x+5], [_y+0.005], marker="${:.1%}$%".format(1-_a), c='#D81B60', s=1000)

plt.plot(num_params_list, last_cost_list, label='circuit #15', color='#1E88E5')
for _x, _y, _a in zip(num_params_list, last_cost_list, accuracy_list):
    plt.scatter([_x+3], [_y-0.005], marker="${:.1%}$%".format(1-_a), c='#1E88E5', s=1000)
plt.xlabel("# parameters")
plt.ylabel("training loss")
plt.legend()
plt.tight_layout()

# %%
circuit15_result = dict(
    accuracy_list = accuracy_list,
    num_params_list = num_params_list,
    last_cost_list = last_cost_list,
    qasvm_list = qasvm_list,
    result_list = result_list,
)

circuit9_result = dict(
    accuracy_list = _accuracy_list,
    num_params_list = _num_params_list,
    last_cost_list = _last_cost_list,
    qasvm_list = _qasvm_list,
    result_list = _result_list,
)

import dill

# with open(f'./circuit15result(label{label_index})', 'wb') as fp:
#     dill.dump(circuit15_result, fp)
# with open(f'./circuit9result(label{label_index})', 'wb') as fp:
#     dill.dump(circuit9_result, fp)
